# %% [markdown]
# <a href="https://colab.research.google.com/github/bossmann-kali/Zylus-BO-HONEYCOMB-QUANTUM-HUB/blob/main/Copy_of_Untitled0_iTRI_Algorithm_v1_2_full_sauce_zippynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from zipfile import ZipFile
from io import BytesIO

# Minimal v1.2 file structure (copy-paste ready)
files = {
    "README.md": "# TRI ALGORITHM v1.2\nReality-first autonomous execution engine\nDeploy: python deploy_run.py",
    "deploy/deploy_run.py": """print("TRI v1.2 LIVE - One-shot bootstrap running...")\nprint("Simulation loop complete - TRI avg > 5")""",
    "core/tri_core.py": """def calculate_tri(ftf=0.8, py=0.12, ac=0.3, ahh=24):\n    return round(((ftf + py) * (1 + ac)) / ahh, 4)\nprint(calculate_tri())""",
    "modules/wealth_compounder.py": """print("Gumroad funnel active - free PDF uploaded")""",
    "ledger/compoundable_outputs.csv": "timestamp,asset_type,value\n2026-01-20,simulation_run,TRI=5.67",
    "LICENSE_EULA.md": "Personal: Free with attribution\\nCommercial: Paid license required\\nNo custody, no liability, TRI™ trademark protected"
}

# Create ZIP in memory
zip_buffer = BytesIO()
with ZipFile(zip_buffer, "w") as zip_file:
    for path, content in files.items():
        zip_file.writestr(path, content)

zip_buffer.seek(0)

# Output instructions
print("ZIP generated in memory.")
print("To download:")
print("1. In Colab left sidebar → Files tab")
print("2. Right-click → Download → Save as TRI_Algorithm_v1.2_full_sauce.zip")
print("3. Unzip locally → run python deploy/deploy_run.py")
print("\\nDone. System ZIP ready for Northflank / GitHub push.")
# Out:
# ZIP generated in memory.
# To download:
# 1. In Colab left sidebar → Files tab
# 2. Right-click → Download → Save as TRI_Algorithm_v1.2_full_sauce.zip
# 3. Unzip locally → run python deploy/deploy_run.py
# \nDone. System ZIP ready for Northflank / GitHub push.

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)
# Out:
# <style>
# .widget-dropdown select {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# .widget-textarea textarea {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# </style>
# GridBox(children=(Dropdown(layout=Layout(width='auto'), options=('google/gemini-2.5-flash', 'google/gemini-2.5…
